# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataset = 'SMD'
test = np.load(f'dataset\{dataset}\{dataset}_test.npy')
label = np.load(f'dataset\{dataset}\{dataset}_test_label.npy')

# %%
print(test.shape)
print(label.shape)
# Out:
# (708420, 38)
# (708420,)

# %%
plt.figure(figsize=(14, 6))
for i in range(38):
    plt.plot(test[10000:12000,i])
    plt.plot(label[10000:12000])
    plt.show()
